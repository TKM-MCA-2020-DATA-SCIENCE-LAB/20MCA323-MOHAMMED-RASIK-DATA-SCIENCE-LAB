# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('/content/sample_data/data.csv')
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
plt.figure(figsize=[17,9])
sb.countplot(df['diagnosis'].value_counts())
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
#droping feature
df.drop(['Unnamed: 32','id'],axis=1,inplace=True)

# %%
# independent variables
x = df.drop('diagnosis',axis=1)
#dependent variables
y = df.diagnosis

# %%
from sklearn.preprocessing import LabelEncoder
#creating the object
lb = LabelEncoder()
y = lb.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=40)

# %%
#importing StandardScaler
from sklearn.preprocessing import StandardScaler
#creating object
sc = StandardScaler()
xtrain = sc.fit_transform(xtrain)
xtest = sc.transform(xtest)

# %%
#importing keras
import keras
#importing sequential module
from keras.models import Sequential
# import dense module for hidden layers
from keras.layers import Dense
#importing activation functions
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout

# %%
#creating model
classifier = Sequential()

# %%
#first hidden layer
classifier.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu',input_dim=30))
#second hidden layer
classifier.add(Dense(units=9,kernel_initializer='he_uniform',activation='relu'))
# last layer or output layer
classifier.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))

# %%
#taking summary of layers
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 9)                 279
#
#  dense_1 (Dense)             (None, 9)                 90
#
#  dense_2 (Dense)             (None, 1)                 10
#
# =================================================================
# Total params: 379
# Trainable params: 379
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compiling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
 #fitting the ANN to the training set
model = classifier.fit(xtrain,ytrain,batch_size=100,epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 4ms/step - loss: 0.5178 - accuracy: 0.7563
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4626 - accuracy: 0.7965
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4107 - accuracy: 0.8241
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3671 - accuracy: 0.8392
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3315 - accuracy: 0.8568
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3030 - accuracy: 0.8744
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2787 - accuracy: 0.8869
# Epoch 8/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2578 - accuracy: 0.8995
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2415 - accuracy: 0.9020
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2269 - accuracy: 0.9095
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2149 - accuracy: 0.9121
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2047 - accuracy: 0.9171
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1966 - accuracy: 0.9196
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1885 - accuracy: 0.9246
# Epoch 15/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1816 - accuracy: 0.9271
# Epoch 16/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9271
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1700 - accuracy: 0.9271
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1649 - accuracy: 0.9296
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1603 - accuracy: 0.9322
# Epoch 20/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1562 - accuracy: 0.9322
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9347
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1491 - accuracy: 0.9347
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1459 - accuracy: 0.9397
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9422
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.9422
# Epoch 26/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.9447
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9447
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1327 - accuracy: 0.9447
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1305 - accuracy: 0.9447
# Epoch 30/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1284 - accuracy: 0.9472
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9472
# Epoch 32/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1247 - accuracy: 0.9472
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9472
# Epoch 34/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.9447
# Epoch 35/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1195 - accuracy: 0.9472
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1179 - accuracy: 0.9472
# Epoch 37/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1163 - accuracy: 0.9472
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1148 - accuracy: 0.9497
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9497
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1119 - accuracy: 0.9497
# Epoch 41/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1106 - accuracy: 0.9497
# Epoch 42/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.9497
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1079 - accuracy: 0.9497
# Epoch 44/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1066 - accuracy: 0.9497
# Epoch 45/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9497
# Epoch 46/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.9497
# Epoch 47/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9523
# Epoch 48/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9548
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9548
# Epoch 50/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1001 - accuracy: 0.9548
# Epoch 51/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0991 - accuracy: 0.9548
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9548
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9548
# Epoch 54/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9548
# Epoch 55/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0951 - accuracy: 0.9548
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9548
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9548
# Epoch 58/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 0.9548
# Epoch 59/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 0.9548
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0904 - accuracy: 0.9548
# Epoch 61/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0894 - accuracy: 0.9573
# Epoch 62/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9598
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0877 - accuracy: 0.9598
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0868 - accuracy: 0.9648
# Epoch 65/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.9648
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0853 - accuracy: 0.9648
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0845 - accuracy: 0.9673
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0837 - accuracy: 0.9673
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9673
# Epoch 70/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9698
# Epoch 71/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0814 - accuracy: 0.9698
# Epoch 72/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9698
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0800 - accuracy: 0.9698
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 0.9698
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9698
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0779 - accuracy: 0.9698
# Epoch 77/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0772 - accuracy: 0.9698
# Epoch 78/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0766 - accuracy: 0.9698
# Epoch 79/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0760 - accuracy: 0.9698
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0752 - accuracy: 0.9698
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 0.9698
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0741 - accuracy: 0.9698
# Epoch 83/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9698
# Epoch 84/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9698
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0722 - accuracy: 0.9673
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0716 - accuracy: 0.9698
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9698
# Epoch 88/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0705 - accuracy: 0.9698
# Epoch 89/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0699 - accuracy: 0.9698
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9698
# Epoch 91/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0689 - accuracy: 0.9698
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0683 - accuracy: 0.9698
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9698
# Epoch 94/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9698
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9698
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9724
# Epoch 97/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9749
# Epoch 98/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9749
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0649 - accuracy: 0.9749
# Epoch 100/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9774

# %%
#now testing for Test data
y_pred = classifier.predict(xtest)

# %%
#converting values
y_pred = (y_pred>0.5)
print(y_pred)
# Out:
# [[False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
cm = confusion_matrix(ytest,y_pred)
score = accuracy_score(ytest,y_pred)
print(cm)
print('score is:',score)
# Out:
# [[113   2]
#  [  1  55]]
# score is: 0.9824561403508771

# %%
# creating heatmap of comfussion matrix
plt.figure(figsize=[14,7])
sb.heatmap(cm,annot=True)
plt.show()

# %%
# list all data in history
print(model.history.keys())
# summarize history for accuracy
plt.plot(model.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
# summarize history for loss
plt.plot(model.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#saving the model
classifier.save('File_name.h5')
